# %% [markdown]
# # Pogil Activity on Chapter 4: Loops

# %% [markdown]
# ## Model 1: Two C++ Programs

# %% [markdown]
# Run the following to create a `main.cpp` file.

# %%
# %%writefile main.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#   string name;
#   cout << "Enter your name: ";
#   cin >> name;
#   int x = 0;
#   while (x < 5) {
#     cout << name << endl;
#     x = x + 1;
#   }
#   cout << "Nice to meet you!" << endl;
#   return 0;
# }

# %% [markdown]
# Run the following to compile and execute the program.

# %%
# %%script bash
# g++ main.cpp -o main && echo "Adam" | ./main

# %% [markdown]
# Run the following block to replace `main.cpp` with a new program.

# %%
# %%writefile main.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#   string name;
#   cout << "Enter your name: ";
#   cin >> name;
#   for (int x = 0; x < 5; x += 1) {
#     cout << name << endl;
#   }
#   cout << "Nice to meet you!" << endl;
#   return 0;
# }

# %% [markdown]
# Run the following block to compile and execute `main.cpp`.

# %%
# %%script bash
# g++ main.cpp -o main && echo "Eve" | ./main

# %% [markdown]
# 1. What is the output of each program? What is the difference in the code?
#
# 2. The first program uses a `while` statement and the second program uses a `for` loop. Identify the parts of each program:
#
#   (a) The _initialization_ statement.
#
#   (b) The _test_ condition.
#
#   (c) The _update_ statement.
#
# 3. You should have observed that the programs are equivalent. Which is more concise?

# %% [markdown]
# 4. What output will each of code snippets produce?
# ```
# for (int i = 0; i < 5; i += 1) {
#   cout << i << " ";
# }
# ```
# ```
# for (int i = 1; i < 5; i += 1) {
#   cout << i << " ";
# }
# ```
# ```
# for (int i = 2; i <= 6; i += 1) {
#   cout << i << " ";
# }
# ```
# ```
# for (int i = 2; i <= 6; i += 2) {
#   cout << i << " ";
# }
# ```

# %% [markdown]
# 5. Complete the missing code in the `for` loops below so that they print the indicated output.
#
#   (a) Even numbers from 100 to 200, inclusive.
#
#   ```
# for (                     ) {
#   cout << i << " ";
# }
#   ```
#
#   (b) `5 4 3 2 1 0`
#
#   ```
# for (                     ) {
#   cout << i << " ";
# }
#   ```

# %% [markdown]
# 6. Based on your solutions above, answer the following questions about the `for` loop.
#
#   (a) Why do we start a `for` loop with something like `int i = 1` instead of `int i == 1`?
#   <br><br>
#   (b) Do you think we always need the `int` in front of the `i = 1` in the for loop initialization?
#   <br><br>
#   (c) Is it better to use a `for` loop when you know how many times the loop should execute (_counter-controlled_) or when you don't know (_sentinel-controlled_)?
#   <br><br>

# %% [markdown]
# 7. Rewrite the following `while` loop as a `for` loop that does the same thing.
# ```
# int cnt = 20;
# while (cnt >= 10) {
#   cnt -= 2;
#   cout << cnt << " ";
# }
# ```

# %% [markdown]
# ## Model 2: Increment / Decrement Operations
#
# | Initial _x_ Value | Statement | Final _y_ Value | Final _x_ Value |
# | :-: | :-: | :-: | :-: |
# |  2  | `y = x++;` |  2  |  3  |
# |  2  | `y = ++x;` |  3  |  3  |
# |  2  | `y = x--;` |  2  |  1  |
# |  2  | `y = --x;` |  1  |  1  |
#
# Refer to this model as your team develops consensus answers to the questions below.

# %% [markdown]
# 8. Based on the model above, describe what each operator does.
#
#   (a) `x++`
#   <br><br>
#   (b) `++x`
#   <br><br>
#   (c) `x--`
#   <br><br>
#   (d) `--x`

# %% [markdown]
# 9. Rewrite the following `for` loop to use an _increment_ operator.
# ```
# for (int i = 5; i <= 10; i += 1) {
#   cout << i << " ";
# }
# ```
#
# 10. Rewrite the following `while` loop to use a _decrement_ operator.
# ```
# int counter = 10;
# while (counter > 0) {
#   cout << "text" << endl;
#   counter = counter - 1;
# }
# ```
#
# 11. Why are increment and decrement operators especially useful for counters?
# <br><br><br><br>
#
# 12. Note that there are two versions of the _increment_ operator: a _pre-increment_ version (`++x`) and a _post-increment_ version (`x++`). The same is true of the decrement operator. Use the following code to assist as you complete the missing entries in the table below.
#
# | Initial _x_ Value | Expression | Expression Value | Final _x_ Value |
# | :-: | :-: | :-: | :-: |
# |  5  | `3 + 2 * (x++)` |     |  6  |
# |  3  | `5 - (++x) / 2` |  3  |     |
# |     | `6 * (--x)`     |  0  |  0  |
# | -3  |                 | -1  | -4  |

# %%
# %%writefile main.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#
#   // define our variable
#   int x;
#
#   // row one
#   x = 5;
#   cout << "Expression: Value " << (3 + 2 * (x++)) << endl;
#   cout << "x Value: " << x << endl << endl;
#
#   // row two
#   x = 3;
#   cout << "Expression: Value " << (5 - (++x) / 2) << endl;
#   cout << "x Value: " << x << endl << endl;
#
#   // row three
#   x = 1;
#   cout << "Expression: Value " << (6 * (--x)) << endl;
#   cout << "x Value: " << x << endl << endl;
#
#   // row four
#   x = -3;
#   cout << "Expression: Value " << (2 + (x--)) << endl;
#   cout << "x Value: " << x << endl << endl;
# }

# %%
# %%script bash
# g++ main.cpp -o main | ./main

# %% [markdown]
# 13. Based on your work above, what is the difference between the pre- and post- versions of these operators?

# %% [markdown]
# ## Model 3: A C++ Nested Loop Program

# %%
# %%writefile main.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#   string name;
#   cout << "What is your name? ";
#   cin >> name;
#   for (int i = 0; i < 5; i++) {
#     for (int j = 0; j < 3; j++) {
#       cout << name << " ";
#     }
#     cout << endl;
#   }
# }

# %% [markdown]
# Refer to Model 3 above as your team develops consensus answers to the questions below.
#
# 14. What does this program display? Try to determine this without running it first, then check your work by running it.
#   <br><br>

# %%
# %%script bash
# g++ main.cpp -o main | echo "Cain" | ./main

# %% [markdown]
# 15. Answer the following questions regarding the loops in this code snippet.
#
#   (a) How many loops are in this code?
#   <br><br>
#   (b) Does one loop completely finish before the next loop begins?
#   <br><br>
#   (c) What do you call this arrangement of loops?
#   <br><br>
#
# 16. How many time does each `cout` statement in this model executed?
#
#   (a) The `cout` prompting for a name?
#   <br><br>
#   (b) The `cout` with the name and a space?
#   <br><br>
#   (c) The `cout` with an `endl`?
#
# 17. A loop that appears within another loop is called a _nested_ loop. We can refer to the two loops as the _outer_ loop and the _inner_ loop.
#
#   (a) Where does the outer loop start?
#   <br><br>
#   (b) Where does the inner loop start?
#   <br><br>
#   (c) Where does the inner loop end?
#   <br><br>
#   (d) Where does the outer loop end?
#   <br><br>
# 18. What do each of the loops do?
#
#   (a) What does the inner loop do?
#   <br><br>
#   (b) What does the outer loop do?
#   <br><br>

# %% [markdown]
# ## Model 4: Output from Several Nested Loops
#
# | Model 4(a) | Model 4(b) | Model 4(c) |
# | :--------: | :--------: | :--------: |
# | * * * * *  | 1 1 1 1 1  | 1 2 3 4 5  |
# | * * * * *  | 2 2 2 2 2  | 1 2 3 4 5  |
# | * * * * *  | 3 3 3 3 3  | 1 2 3 4 5  |
# | * * * * *  | 4 4 4 4 4  | 1 2 3 4 5  |
# | * * * * *  | 5 5 5 5 5  | 1 2 3 4 5  |
# | * * * * *  | 6 6 6 6 6  | 1 2 3 4 5  |
# | * * * * *  | 7 7 7 7 7  | 1 2 3 4 5  |
#
# Refer to Model 4 above as your team develops consesus answers to the questions below.

# %% [markdown]
# 19. There are several ways to write a C++ program that outputs the contents of Model 4(a) above. briefly describe how it could be done using the following methods.
#
#   (a) Using a series of `cout` statements without any loops.
#   <br><br><br><br>
#   (b) Using a single loop (without any nesting).
#   <br><br><br><br>
#
# 20. In this exercise we will create the output in Model 4(a) using nexted loops.
#
#   (a) Surround the `cout` statement below by a `for` loop so that the five `*` characters are printed on a single line.

# %%
# %%writefile main.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#
#   cout << "* ";
#
#   return 0;
# }

# %%
# %%script bash
# g++ main.cpp -o main | ./main

# %% [markdown]
# 20. (continued)
#
#   (b) Now build on the block of code above by wrapping the loop you created in another `for` loop that prints seven of these lines, with an `endl` between each one.
#
# 21. Suppose that `int` variables `rows` and `cols` contain the number of rows and columns of `*`s you wish to print. How would you modify your code above to print out that number of rows and columns? Test your solution below.

# %%
# %%writefile main.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#
#   int rows = 8, cols = 10;
#
#   for (int i = 0; i < 7; i++) {
#     for (int j = 0; j < 5; j++) {
#       cout << "* ";
#     }
#     cout << endl;
#   }
#
#   return 0;
# }

# %%
# %%script bash
# g++ main.cpp -o main | ./main

# %% [markdown]
# 22. How would you modify your code in the previous question to produce the output seen in Model 4(b), assuming the following:
#
# ```
# int rows = 7;
# int cols = 4;
# ```
#
# 23. How would you modify your code so that the output matches Model 4(c).
