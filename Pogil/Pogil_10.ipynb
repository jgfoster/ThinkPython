# %% [markdown]
# # Pogil 10: Dictionaries
#
# ## Model 1: Simple Dictionaries
#
# In our last Pogil activity, we included the following example of a list:
#
# `students = ['Jones', 3.4, 'Hernandez', 3.6]`
#
# Try out the following code:

# %%
def main():
  gpa = {
    'Jones': 3.4,
    'Hernandez': 3.6,
    'Martin': 3.4,
    'Lee': 3
  }
  name = input('Enter student name: ')
  print('GPA for', name, 'is', gpa[name])

main()

# %% [markdown]
# 1. How is the syntax used to define `gpa` in this code different from the syntax used to define `students`?
#
# <br>
#
# 2. A _dictionary_ is a Python container used to associate a _key_ and a _value_. The keys can be used to look up the associated values in the dictionary.
#
# (a) What are the keys in the `gpa` dictionary?
#
# (b) What are the values in the `gpa` dictionary?
#
# (c) What is the expression that evaluates to the GPA for Martin?
#
# Try out the following code:

# %%
def main():
  gpa = {
    'Jones': 3.4,
    'Hernandez': 3.6,
    'Martin': 3.4,
    'Lee': 3
  }
  gpa.pop('Martin')
  print(gpa)

main()

# %% [markdown]
# 3. Earlier we learned about the `list.pop` method.
#
# (a) What key and value did `pop` (on line 8) remove from the dictionary?
#
# (b) Replace line 8 with `gpa['Smith'] = 2.9` and run the program. What does this do?
#
# (c) Why might the dictionary used in this model be a better solution for storing GPAs than the list given at the beginning?
#
# <br>
#
# 4. Like a string and a list, a dictionary is considered an iterable. What does a `for` loop iterate over when given a dictionary?

# %%
def main():
  gpa = {
    'Jones': 3.4,
    'Hernandez': 3.6,
    'Martin': 3.4,
    'Lee': 3
  }
  for each in gpa:
    print(each)

main()

# %% [markdown]
# 5. Adapt the `print` statement from question #1 to the code in question #4 to print each student's name and GPA.

# %%
# Your code here

# %% [markdown]
# 6. Write a program to print the average GPA for all students.

# %%
# Your code here

# %% [markdown]
# 7. A dictionary has various methods, including `values`. What does this method return and how could you use it to simplify the code from question #6? Can you eliminate the `for` loop? (Hint: Do you remember a function that calculates the sum of a collection?)

# %%
# Your code here

# %% [markdown]
# ## Model 2: Nested Dictionaries
#
# Consider the following assignment statement:

# %%
crew = {
  'Captain': {
    'first name': 'James',
    'last name': 'Kirk',
    'rank': 'Captain',
    'email': 'capt.kirk@enterprise.com'
  },
  'First Officer': {
    'first name': "S'chn",
    'last name': 'Spock',
    'rank': 'Commander',
    'email': 'mr.logical@enterprise.com'
  }
}

# %% [markdown]
# 8. Just as we can nest lists inside of other lists, dictionaries can be nested inside of other dictionaries.
# The model above contains two dictionaries nested inside of another dictionary.
#
# (a) What term best describes the outer-most dictionary (circle one)?    crew manifest | personnel record
#
# (b) What term best describes the inner dictionaries (circle one)?       crew manifest | personnel record
#
# (c) What are the keys in the outer-most dictionary?
#
# (d) What are the keys in the inner dictionaries?
#
# 9. The email address for Mr. Spock could be retrieved from this dictionary using the following Python expression:
#
# `crew['First Officer']['email']`
#
# Give a similar expression to access each of the following.
#
# (a) The first name of the captain, “James”:
#
# (b) The rank of the first officer, “Commander”:
#
# (c) The email address “capt.kirk@enterprise.com”:
#
# 10. A new crew member, Dr. Leonard McCoy, is to be added as Chief Medical Officer. Dr. McCoy’s rank is Lt. Commander and
# his email address is bones@enterprise.com. Modify and run the code above to incorporate this change.
#
# 11. There have been some updates to the crew information. In each part, write a single line of Python code to make the change then print the crew to confirm the change.
#
# (a) Dr. McCoy has been promoted to the rank of Commander.

# %%
# Your code here
print(crew)

# %% [markdown]
# (b) Mr. Spock has decided that reading email is not logical and wants his email address deleted.

# %%
# Your code here
print(crew)

# %% [markdown]
# (c) Captain Kirk says Spock must have an email address so that he won’t miss out on the Klingon
# memes that the captain likes to forward. Add back Spock’s email address.

# %%
# Your code here
print(crew)

# %% [markdown]
# (d) Mr. Spock takes offense to the Captain’s order and leaves the crew. Delete his personnel record.

# %%
# Your code here
print(crew)

# %% [markdown]
# 12. Write code to print the personnel records in the following format:
#
# `James Kirk (Captain) <capt.kirk@enterprise.com>`

# %%
# Your code here
