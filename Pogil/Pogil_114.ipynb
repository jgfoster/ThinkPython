# %% [markdown]
# # Pogil Activity on Chapter 14:  Inheritance

# %% [markdown]
# ## Model 1: A Credit Card

# %% [markdown]
# <img src="images/credit-card.png" alt="credit card">
#
# Refer to Model 1 above as your group develops consensus answers to the questions below.
#
# 1. List two or more attributes that would be necessary for a class to model a `CreditCard`. Indicate what data types would be most appropriate.
# <br><br><br><br>
#
# 2. When constructing or updating a `CreditCard` objects, what values would you need to check? What are the valid ranges of each attribute?
# <br><br><br><br>
#
# 3. Draw a UML class diagram for your implementation of the `CreditCard` class.
# <br><br><br><br>
#
# 4. Many banks offer `CashBack` credit cards which accumulate a certain number of points for every dollar spent. Other banks offer `TravelRewards` cards which accumulate miles on a particular airline for every dollar spent. What changes would you make to model each of these classes?
# <br><br><br><br>
