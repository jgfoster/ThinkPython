# %% [markdown]
# # Chapter 6a: Lecture Coding Activities

# %% [markdown]
# ## Model 1: Minimum and Maximum
#
# Modify the following as follows:
# * Minimum
#   * Add a `myMin` function that takes two integer arguments and returns the smaller value.
#   * Call the `myMin` function twice from your `main` function with different arguments each time.
# * Maximum
#   * Add a `myMax` function that takes two integer arguments and returns the smaller value.
#   * Call the `myMax` function twice from your `main` function with different arguments each time.
# * Maximum of Three
#   * Define a `maxThree` function that returns the maximum of three integer arguments. Can you do this using the existing myMax function?
# * Middle of Three
#   * Define a `middleOfThree` function that returns the middle value of three integer arguments. Can you do this using the existing functions?

# %%
# %%writefile main.cpp
# #include <iostream> // for std::cin and std::cout
# using namespace std;
#
# // Define myMin
#
# // Define myMax
#
# // Define maxThree
#
# // Define middleOfThree
#
# // Here is the main program
# int main() {
#
#   // Use myMin and myMin Here
#
#   return 0;
# }

# %%
# %%script bash
# g++ main.cpp -o main && ./main

# %% [markdown]
# ## Model 2: Taxes
#
# Modify the following to calculate and print the total cost, including taxes.
#
# * Add a `const double TAX_RATE` "variable" that is initialized to 8.9% (College Place as of January 2025).
# * Update the assignment to `bill` to call `totalCost` and pass in

# %%
# %%writefile main.cpp
# #include <iostream> // for std::cin and std::cout
# #include <iomanip>  // for std::fixed and std::setprecision
# using namespace std;
#
# double totalCost(double bill, double tax) {
#   // INSERT CODE HERE
#
# }
#
# int main() {
#   double price, bill;
#   int count;
#
#   cout << "Enter the number of items purchased: ";
#   cin >> count;
#   cout << "Enter the price per item $";
#   cin >> price;
#
#   bill = count * price;
#
#   cout << endl << "The final bill, including tax, is $";
#   cout << fixed << setprecision(2) << bill << endl;
# }

# %% [markdown]
# Modify the `"5 4.50"` text below to "input" other values.

# %%
# %%script bash
# g++ main.cpp -o main && echo "5 4.50" | ./main

# %% [markdown]
# ## Model 3: Tile Installation
#
# Modify the following to calculate the total cost to install tile.
#
# * Create a function that calculates the total cost to install the tile using the area function and a tax function.
# * Function parameters should be tile cost, room length, and width.
# * In the main program, output the total cost for installing the tile.

# %%
# %%writefile main.cpp
# #include <iostream> // for std::cin and std::cout
# #include <iomanip>  // for std::fixed and std::setprecision
# using namespace std;
#
# double totalArea(double length, double width) {
#   return length * width;
# }
#
# double tileCost() {
#   // Write code here
# }
#
# int main() {
#   double length, width, cost;
#
#   cout << "Room length (ft): ";
#   cin >> length;
#   cout << "Room width (ft): ";
#   cin >> width;
#   cout << "The cost of tile is $";
#   cin >> cost;
#   cout << endl;
#
#   cout << "The total cost to install tile is $";
#   cout << fixed << setprecision(2) << tileCost() << endl;
# }

# %% [markdown]
# Modify the `"20 30 3.75"` text below to "input" other values.

# %%
# %%script bash
# g++ main.cpp -o main && echo "20 30 3.75" | ./main
