# %% [markdown]
# # Project Title
# ### CPTR 141 Final Project
#
# Student Name
#
# ## Introduction
# Write a brief introduction (at least 4 sentences) explaining the dataset you selected and why you are interested in it.
#
# ## Dataset
# Write several paragraphs explaining what information you aim to get from exploring the dataset with python.
#
# Include a link to your [dataset](https://www.kaggle.com/).
#
# Consider listing the columns in your dataset:
#
# * column 1
# * column 2
# * column 3

# %%
'''
Write at least ten (10) functions that provide unique analysis of the data (min, max, average, top 10, or similar ideas).
'''

def main():
  '''
  Write a menu...
  Write at least one user-entered criteria used to customize the analysis ("Select the month/product/range/state/...).
  '''

if __name__ == "__main__":
    main()
# Out:
# Hello from the main program!

# %% [markdown]
# # Conclusion
# Write several sentences (at least 4 sentences) describing what you learned about your dataset while completing this project.
#
# # Reflection
# Write several sentences (at least 4 sentences) reflecting on at least 1 of the questions below:
# - Did you learn something new code wise (i.e. discover a new python library)?
# - What did you struggle with the most with this project?
# - How do you forsee utilizing python in your future?
